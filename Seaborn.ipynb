# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 sns.set(style="white", color_codes=True)
# ----> 3 r, p = pearsonr(df['fare'].dropna(), df['age'].dropna())
#       4 g = sns.jointplot(x='fare', y='age', data=df, kind='scatter', color='steelblue', edgecolor=None, alpha=0.7)
#       5 plt.annotate(f'pearsonr = {r:.3f}; p = {p:.2f}', xy=(0.5, 0.9), xycoords='axes fraction', ha='center', fontsize=12)
#
# NameError: name 'pearsonr' is not defined
